# %%
import json
from PIL import Image
import numpy as np
import cv2

# %%
# Opening JSON file
f = open('sample.json')
 
# returns JSON object as
# a dictionary
data = json.load(f)

# %%
print(data[0])
# Out:
# {'frame_num': 0, 'result_img': [1558339, 2, 1562178, 4, 1566019, 2, 1569859, 1, 1573699, 2, 1577536, 6, 1581374, 8, 1585214, 7, 1589052, 9, 1592891, 11, 1596729, 13, 1600568, 15, 1604408, 15, 1608247, 16, 1612086, 17, 1615926, 16, 1619766, 16, 1623605, 17, 1627445, 17, 1631285, 16, 1635125, 16, 1638965, 16, 1642805, 16, 1646644, 16, 1650484, 16, 1654324, 16, 1658164, 16, 1662004, 16, 1665844, 16, 1669684, 16, 1673447, 6, 1673524, 16, 1677286, 9, 1677365, 15, 1681125, 10, 1681205, 15, 1684965, 10, 1685045, 15, 1688804, 11, 1688885, 15, 1692415, 2, 1692644, 11, 1692725, 15, 1696254, 7, 1696483, 12, 1696565, 15, 1700093, 9, 1700323, 12, 1700405, 15, 1703933, 9, 1704162, 12, 1704244, 16, 1707772, 11, 1708001, 13, 1708084, 16, 1708666, 2, 1711612, 11, 1711839, 15, 1711924, 16, 1712503, 7, 1715452, 11, 1715678, 16, 1715765, 14, 1716342, 9, 1719291, 12, 1719516, 18, 1719605, 14, 1720182, 9, 1723131, 12, 1723355, 19, 1723445, 14, 1724021, 11, 1726970, 13, 1727194, 19, 1727285, 14, 1727860, 1
# ...

# %%
img_arr=data[0]

# %%
print(img_arr.get('result_img'))
# Out:
# [1558339, 2, 1562178, 4, 1566019, 2, 1569859, 1, 1573699, 2, 1577536, 6, 1581374, 8, 1585214, 7, 1589052, 9, 1592891, 11, 1596729, 13, 1600568, 15, 1604408, 15, 1608247, 16, 1612086, 17, 1615926, 16, 1619766, 16, 1623605, 17, 1627445, 17, 1631285, 16, 1635125, 16, 1638965, 16, 1642805, 16, 1646644, 16, 1650484, 16, 1654324, 16, 1658164, 16, 1662004, 16, 1665844, 16, 1669684, 16, 1673447, 6, 1673524, 16, 1677286, 9, 1677365, 15, 1681125, 10, 1681205, 15, 1684965, 10, 1685045, 15, 1688804, 11, 1688885, 15, 1692415, 2, 1692644, 11, 1692725, 15, 1696254, 7, 1696483, 12, 1696565, 15, 1700093, 9, 1700323, 12, 1700405, 15, 1703933, 9, 1704162, 12, 1704244, 16, 1707772, 11, 1708001, 13, 1708084, 16, 1708666, 2, 1711612, 11, 1711839, 15, 1711924, 16, 1712503, 7, 1715452, 11, 1715678, 16, 1715765, 14, 1716342, 9, 1719291, 12, 1719516, 18, 1719605, 14, 1720182, 9, 1723131, 12, 1723355, 19, 1723445, 14, 1724021, 11, 1726970, 13, 1727194, 19, 1727285, 14, 1727860, 12, 1730809, 14, 1731033, 20, 17
# ...

# %%
def rle_decode(mask_rle, shape):
    """
    mask_rle: run-length as string formatted (start length)
    shape: (width, height) of array to return
    Returns numpy array, 1 - mask, 0 - background
    """
    s = mask_rle
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    shape = shape[1], shape[0]
    img = np.zeros(shape[0] * shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape)

# %%
result_img=rle_decode(img_arr.get('result_img'), (3840,2160))

# %%
cv2.imwrite("Result Image.jpg", result_img*100)
# Out:
# True

# %% [markdown]
# ## RLE Encoding Function

# %%
# def rle_encode(mask_image):
#     pixels = mask_image.flatten()
#     pixels[0] = 0
#     pixels[-1] = 0
#     runs = torch.where(pixels[1:] != pixels[:-1])[0] + 2
#     runs[1::2] = runs[1::2] - runs[:-1:2]
#     runs=[int(x) for x in runs]
#     return runs

# %% [markdown]
# ## Json Writing Procedure with dictonary like structure

# %%
# json_data=[] #should be defined before loop or in the start
# diction ={'frame_num': frame_num, 'result_img':result_img}

# json_data.append(diction)
# # print(json_data, flush = True)
# with open("sample.json", "w") as outfile:
#     json.dump(json_data, outfile)
